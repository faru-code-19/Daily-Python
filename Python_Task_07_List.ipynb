# %% [markdown]
# ## 1.Create an empty list of numbers. Append 10, 20, and 30 to it. Then change the second element to 25 and print the updated list.
# Input:
# numbers = []
#
# Output:
#
# [10, 25, 30]

# %%
lst=[]
lst.append(10)
lst.append(20)
lst.append(30)
print(lst)
lst[1]=25
print(lst)
# Out:
# [10, 20, 30]
# [10, 25, 30]

# %% [markdown]
# ## 2. Given a list of colors, retrieve and prinhe first and last elements using indexing.
# Input:
#
# colors = ['red', 'blue', 'green', 'yellow']
#
# Output:
#
# red
#
# yellow

# %%
colors = ['red', 'blue', 'green', 'yellow']
print("first element--",colors[0])
print("last element--",colors[-1])
# Out:
# first element-- red
# last element-- yellow

# %% [markdown]
# ## 3. Slice the list fruits to extract only 'banana' and 'orange'
#
# Input:
#
# fruits = ['apple', 'banana', 'orange', 'grapes', 'mango']
#
# Output:
#
# ['banana', 'orange']

# %%
fruits = ['apple', 'banana', 'orange', 'grapes', 'mango']
print(fruits[1:3])
# Out:
# ['banana', 'orange']

# %% [markdown]
# ## 4. Reverse the given list using slicing.
# Input:
#
# numbers = [1, 2, 3, 4, 5]
#
# Output:
#
# [5, 4, 3, 2, 1]

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers[::-1])
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 5. Count how many times 'apple' appears in the list.
# Input:
#
# fruits = ['apple', 'banana', 'apple', 'orange', 'apple']
#
# Output:
#
# 3

# %%
fruits = ['apple', 'banana', 'apple', 'orange', 'apple']
cnt=0
for i in fruits:
    if i=='apple':
        cnt=cnt+1
print(cnt)
# Out:
# 3

# %% [markdown]
# ## 6. Combine two lists into one.
# Input:
#
# list1 = [1, 2, 3]
#
# list2 = [4, 5, 6]
#
# Output:
#
# [1, 2, 3, 4, 5, 6]

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
#concatenation
print(list1+list2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## 7. Insert 'watermelon' at index 2 in the list.
# Input:
#
# fruits = ['apple', 'banana', 'orange', 'mango']
#
# Output:
#
# ['apple', 'banana', 'watermelon', 'orange', 'mango']

# %%
fruits = ['apple', 'banana', 'orange', 'mango']
fruits.insert(2,'watermelon')
print(fruits)
# Out:
# ['apple', 'banana', 'watermelon', 'orange', 'mango']

# %% [markdown]
# ## 8. Remove 'orange' from the updated fruits list

# %%
fruits.remove('orange')
print(fruits)
# Out:
# ['apple', 'banana', 'watermelon', 'mango']

# %% [markdown]
# ## 9. Remove the third element from the updated fruits list.

# %%
fruits.pop(2)
print(fruits)
# Out:
# ['apple', 'banana']

# %% [markdown]
# ## 10. Access 6000 from the nested list.
# Input:
#
# nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# %%
nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
print(nested_list[2][2][1])
# Out:
# 6000

# %% [markdown]
# ## 11. Add 7000 after 6000 inside the nested list.
# Input:
#
# nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
#
# Output:
#
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
nested_list = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
nested_list[2][2].append(7000)
print(nested_list)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# ## 12. Replace the first occurrence of 20 with 200.
# Input:
#
# numbers = [5, 10, 15, 20, 25, 50, 20]
#
# Output:
#
# [5, 10, 15, 200, 25, 50, 20]
#
# b
#
# 98

# %%
numbers = [5, 10, 15, 20, 25, 50, 20]
for i in range(len(numbers)):
    if numbers[i]==20:
        numbers[i]=200
        break
print(numbers)
# Out:
# [5, 10, 15, 200, 25, 50, 20]
